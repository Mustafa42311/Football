# %%
import pandas as pd
import requests

# %%
#df = pd.read_html('https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats',
                  #attrs={"id":"compare_standard"})

# %%
response = requests.get('https://fbref.com/en/comps/Big5/stats/players/Big-5-European-Leagues-Stats')

# %%
response.status_code
# Out:
# 403
