# %%
import json
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service as ChromeService

from webdriver_manager.chrome import ChromeDriverManager

# %%
options = webdriver.ChromeOptions()
options.set_capability(
    "goog:loggingPrefs", {"performance": "ALL", "browser": "ALL"}
)


driver = webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()), options=options)

# %%
driver.set_page_load_timeout(10)

try:
    driver.get("https://www.sofascore.com/football/match/deportivo-alaves-barcelona/rgbsKhb#id:14083144,tab:statistics")
except:
    pass


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
logs_raw = driver.get_log("performance")

# %%
logs = [json.loads(lr["message"])["message"] for lr in logs_raw]

# %%
logs[0]
# Out:
# {'method': 'Network.policyUpdated', 'params': {}}

# %%
for x in logs:
    if 'shotmap' in x['params'].get('headers', {}).get(':path', ''):
        print(x['params'].get('headers', {}).get(':path'))
        break
# Out:
# /api/v1/event/14083144/shotmap

# %%
x
# Out:
# {'method': 'Network.requestWillBeSentExtraInfo',
#  'params': {'associatedCookies': [{'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1798388482,
#      'httpOnly': False,
#      'name': 'FCCDCF',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'secure': False,
#      'session': False,
#      'size': 162,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': '%5Bnull%2Cnull%2Cnull%2Cnull%2Cnull%2Cnull%2C%5B%5B32%2C%22%5B%5C%226ca3eed5-0e39-4c0d-bafd-df0c1aa9fef3%5C%22%2C%5B1764692482%2C345000000%5D%5D%22%5D%5D%5D'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1798388483,
#      'httpOnly': False,
#      'name': '__gads',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'sameSite': 'None',
#      'secure': True,
#      'session': False,
#      'size': 89,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': 'ID=99709d5696527164:T=1764692483:RT=1764692483:S=ALNI_MbglyEm5-MQScWibCBecmd59iLwPQ'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1798388483,
#      'httpOnly': False,
#      'name': '__gpi',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'sameSite': 'None',
#      'secure': True,
#      'session': False,
#      'size': 89,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': 'UID=000012d14772569e:T=1764692483:RT=1764692483:S=ALNI_MZ3kXt97PQPh5y7qbjnN5FeWbcFLA'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1780244483,
#      'httpOnly': False,
#      'name': '__eoi',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'sameSite': 'None',
#      'secure': True,
#      'session': False,
#      'size': 82,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': 'ID=3e4fc124de118011:T=1764692483:RT=1764692483:S=AA-AfjbcctsN_02CXPuX0T1E5HNn'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1765297283,
#      'httpOnly': False,
#      'name': 'panoramaId_expiry',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'sameSite': 'Lax',
#      'secure': False,
#      'session': False,
#      'size': 30,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': '1765297283174'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1788020483,
#      'httpOnly': False,
#      'name': '_cc_id',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'sameSite': 'Lax',
#      'secure': False,
#      'session': False,
#      'size': 38,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': '6cdd9294a89d49251f2932a410d5a744'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1765297283,
#      'httpOnly': False,
#      'name': 'panoramaId',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'sameSite': 'Lax',
#      'secure': False,
#      'session': False,
#      'size': 74,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': '27e0d082806f8bed0fdb13c565e4185ca02c7d713e9b8d91e1084aaf1c37d4bf'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1798395682,
#      'httpOnly': False,
#      'name': 'cto_bundle',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'secure': False,
#      'session': False,
#      'size': 196,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': 'f3zkH19yeGtFRlBObjZPbk5MWVBSQ1JyMCUyQk1Gc01veTd3WUNXeVp6NGdLNnRGNTRyNDRUR1d4S1RmSUEyJTJCMTdFVDlWSUZPR3JERjlrQkQ3bXhJOUhydkVtUzUyb09DMWE5cThhYk56V1l3cFRJQnZYbVJmZEVlemVOakIlMkY4UWN6Q3hXYQ'},
#     'exemptionReason': 'None'},
#    {'blockedReasons': [],
#     'cookie': {'domain': '.sofascore.com',
#      'expires': 1798395682,
#      'httpOnly': False,
#      'name': 'cto_bidid',
#      'path': '/',
#      'priority': 'Medium',
#      'sameParty': False,
#      'secure': False,
#      'session': False,
#      'size': 152,
#      'sourcePort': 443,
#      'sourceScheme': 'Secure',
#      'value': 'pdlonF9tYk9BRXdiUnR6TnA4eVVtYU5WbTBWWUc4MUlxVjVzdThwMTlpWnklMkJBWGV0MjJ3JTJGSzZ5Q3NXUEZpdmR3elpwJTJGRVJ5V1N3JTJGY1dqUExLdkpsM3ElMkZFdkElM0QlM0Q'},
#     'exemptionReason': 'None'}],
#   'clientSecurityState': {'initiatorIPAddressSpace': 'Public',
#    'initiatorIsSecureContext': True,
#    'privateNetworkRequestPolicy': 'PermissionBlock'},
#   'connectTiming': {'requestTime': 8307.082426},
#   'headers': {':authority': 'www.sofascore.com',
#    ':method': 'GET',
#    ':path': '/api/v1/event/14083144/shotmap',
#    ':scheme': 'https',
#    'accept': '*/*',
#    'accept-encoding': 'gzip, deflate, br, zstd',
#    'accept-language': 'en-US,en;q=0.9',
#    'baggage': 'sentry-environment=production,sentry-release=yHMUTokBj_HIEk1DcD-em,sentry-public_key=d693747a6bb242d9bb9cf7069fb57988,sentry-trace_id=2506ed24850b53a28ad7ea55fc07ebe7',
#    'cache-control': 'max-age=0',
#    'cookie': 'FCCDCF=%5Bnull%2Cnull%2Cnull%2Cnull%2Cnull%2Cnull%2C%5B%5B32%2C%22%5B%5C%226ca3eed5-0e39-4c0d-bafd-df0c1aa9fef3%5C%22%2C%5B1764692482%2C345000000%5D%5D%22%5D%5D%5D; __gads=ID=99709d5696527164:T=1764692483:RT=1764692483:S=ALNI_MbglyEm5-MQScWibCBecmd59iLwPQ; __gpi=UID=000012d14772569e:T=1764692483:RT=1764692483:S=ALNI_MZ3kXt97PQPh5y7qbjnN5FeWbcFLA; __eoi=ID=3e4fc124de118011:T=1764692483:RT=1764692483:S=AA-AfjbcctsN_02CXPuX0T1E5HNn; panoramaId_expiry=1765297283174; _cc_id=6cdd9294a89d49251f2932a410d5a744; panoramaId=27e0d082806f8bed0fdb13c565e4185ca02c7d713e9b8d91e1084aaf1c37d4bf; cto_bundle=f3zkH19yeGtFRlBObjZPbk5MWVBSQ1JyMCUyQk1Gc01veTd3WUNXeVp6NGdLNnRGNTRyNDRUR1d4S1RmSUEyJTJCMTdFVDlWSUZPR3JERjlrQkQ3bXhJOUhydkVtUzUyb09DMWE5cThhYk56V1l3cFRJQnZYbVJmZEVlemVOakIlMkY4UWN6Q3hXYQ; cto_bidid=pdlonF9tYk9BRXdiUnR6TnA4eVVtYU5WbTBWWUc4MUlxVjVzdThwMTlpWnklMkJBWGV0MjJ3JTJGSzZ5Q3NXUEZpdmR3elpwJTJGRVJ5V1N3JTJGY1dqUExLdkpsM3ElMkZFdkElM0QlM0Q',
#    'priority': 'u=1, i',
#    'referer': 'https://www.sofascore.com/football/match/deportivo-alaves-barcelona/rgbsKhb',
#    'sec-ch-ua': '"Chromium";v="142", "Google Chrome";v="142", "Not_A Brand";v="99"',
#    'sec-ch-ua-mobile': '?0',
#    'sec-ch-ua-platform': '"Linux"',
#    'sec-fetch-dest': 'empty',
#    'sec-fetch-mode': 'cors',
#    'sec-fetch-site': 'same-origin',
#    'sentry-trace': '2506ed24850b53a28ad7ea55fc07ebe7-b7702ae99ebe17de',
#    'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/142.0.0.0 Safari/537.36',
#    'x-requested-with': '4c3fe8'},
#   'requestId': '30968.628',
#   'siteHasCookieInOtherPartition': False}}

# %%
shotmap = json.loads(driver.execute_cdp_cmd('Network.getResponseBody', {'requestId': x["params"]["requestId"]})['body'])['shotmap']

# %%
shotmap
# Out:
# [{'player': {'name': 'Dani Olmo',
#    'slug': 'dani-olmo',
#    'shortName': 'D. Olmo',
#    'position': 'M',
#    'jerseyNumber': '20',
#    'userCount': 194438,
#    'gender': 'M',
#    'sofascoreId': 'DaniOlmo',
#    'id': 789071,
#    'fieldTranslations': {'nameTranslation': {'ar': 'داني أولمو'},
#     'shortNameTranslation': {'ar': 'د. أولمو',
#      'hi': 'डी. ओल्मो',
#      'bn': 'ডি. ওলমো'}}},
#   'isHome': True,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'fast-break',
#   'playerCoordinates': {'x': 13, 'y': 45.4, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 46.6, 'z': 3.2},
#   'xg': 0.48045688867569,
#   'xgot': 0.80454111099243,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266674,
#   'time': 90,
#   'addedTime': 3,
#   'timeSeconds': 5548,
#   'draw': {'start': {'x': 45.4, 'y': 13},
#    'end': {'x': 53.4, 'y': 0},
#    'goal': {'x': 53.4, 'y': 96.8}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 752,
#   'periodTimeSeconds': 148,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Jon Pacheco',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'jon-pacheco',
#    'shortName': 'J. Pacheco',
#    'position': 'D',
#    'jerseyNumber': '5',
#    'userCount': 468,
#    'gender': 'M',
#    'id': 934383,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جون باتشيكو',
#      'hi': 'जॉन पचेको',
#      'bn': 'জন পাচেকো'},
#     'shortNameTranslation': {'ar': 'ج. باتشيكو',
#      'hi': 'जे. पचेको',
#      'bn': 'জে. পাচেকো'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 9.8, 'y': 49, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'left',
#   'goalMouthCoordinates': {'x': 0, 'y': 63.9, 'z': 5.6},
#   'blockCoordinates': {'x': 4.6, 'y': 40.1, 'z': 0},
#   'xg': 0.060231875628233,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6266536,
#   'time': 78,
#   'timeSeconds': 4656,
#   'draw': {'start': {'x': 49, 'y': 9.8},
#    'block': {'x': 40.1, 'y': 4.6},
#    'end': {'x': 36.1, 'y': 0},
#    'goal': {'x': 36.1, 'y': 94.4}},
#   'reversedPeriodTime': 13,
#   'reversedPeriodTimeSeconds': 744,
#   'periodTimeSeconds': 1956,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lucas Boyé',
#    'slug': 'lucas-boye',
#    'shortName': 'L. Boyé',
#    'position': 'F',
#    'jerseyNumber': '15',
#    'userCount': 1118,
#    'gender': 'M',
#    'id': 814385,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لوكاس بويه',
#      'hi': 'लुकास बोये',
#      'bn': 'লুকাস বোয়ে'},
#     'shortNameTranslation': {'ar': 'ل. بويه',
#      'hi': 'एल. बोये',
#      'bn': 'এল. বোয়ে'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 8.2, 'y': 56.2, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.3, 'z': 19},
#   'blockCoordinates': {'x': 6.3, 'y': 54.7, 'z': 0},
#   'xg': 0.10504229366779,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6266523,
#   'time': 78,
#   'timeSeconds': 4623,
#   'draw': {'start': {'x': 56.2, 'y': 8.2},
#    'block': {'x': 54.7, 'y': 6.3},
#    'end': {'x': 49.7, 'y': 0},
#    'goal': {'x': 49.7, 'y': 81}},
#   'reversedPeriodTime': 13,
#   'reversedPeriodTimeSeconds': 777,
#   'periodTimeSeconds': 1923,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Marc Casadó',
#    'slug': 'marc-casado',
#    'shortName': 'M. Casadó',
#    'position': 'M',
#    'jerseyNumber': '17',
#    'userCount': 62215,
#    'gender': 'M',
#    'sofascoreId': 'marccasado',
#    'id': 1000483,
#    'fieldTranslations': {'nameTranslation': {'ar': 'مارك كاسادو',
#      'hi': 'मार्क कैसाडो',
#      'bn': 'মার্ক কাসাডো'},
#     'shortNameTranslation': {'ar': 'م. كاسادو',
#      'hi': 'एम. कैसाडो',
#      'bn': 'এম. কাসাডো'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 22.6, 'y': 55.4, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 48.2, 'z': 19},
#   'blockCoordinates': {'x': 12.4, 'y': 53.8, 'z': 0},
#   'xg': 0.03662321344018,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266543,
#   'time': 74,
#   'timeSeconds': 4396,
#   'draw': {'start': {'x': 55.4, 'y': 22.6},
#    'block': {'x': 53.8, 'y': 12.4},
#    'end': {'x': 51.8, 'y': 0},
#    'goal': {'x': 51.8, 'y': 81}},
#   'reversedPeriodTime': 17,
#   'reversedPeriodTimeSeconds': 1004,
#   'periodTimeSeconds': 1696,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lamine Yamal',
#    'slug': 'lamine-yamal',
#    'shortName': 'L. Yamal',
#    'position': 'M',
#    'jerseyNumber': '10',
#    'userCount': 1472275,
#    'gender': 'M',
#    'sofascoreId': 'Lamiyamal',
#    'id': 1402912,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'},
#     'shortNameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 15, 'y': 53.6, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 26.9, 'z': 20.8},
#   'blockCoordinates': {'x': 1.1, 'y': 71.7, 'z': 0},
#   'xg': 0.042417280375957,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266519,
#   'time': 74,
#   'timeSeconds': 4382,
#   'draw': {'start': {'x': 53.6, 'y': 15},
#    'block': {'x': 71.7, 'y': 1.1},
#    'end': {'x': 73.1, 'y': 0},
#    'goal': {'x': 73.1, 'y': 79.2}},
#   'reversedPeriodTime': 17,
#   'reversedPeriodTimeSeconds': 1018,
#   'periodTimeSeconds': 1682,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lamine Yamal',
#    'slug': 'lamine-yamal',
#    'shortName': 'L. Yamal',
#    'position': 'M',
#    'jerseyNumber': '10',
#    'userCount': 1472275,
#    'gender': 'M',
#    'sofascoreId': 'Lamiyamal',
#    'id': 1402912,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'},
#     'shortNameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 15.6, 'y': 51.5, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.2, 'z': 19},
#   'blockCoordinates': {'x': 12.1, 'y': 50.9, 'z': 0},
#   'xg': 0.088216871023178,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266497,
#   'time': 74,
#   'timeSeconds': 4380,
#   'draw': {'start': {'x': 51.5, 'y': 15.6},
#    'block': {'x': 50.9, 'y': 12.1},
#    'end': {'x': 48.8, 'y': 0},
#    'goal': {'x': 48.8, 'y': 81}},
#   'reversedPeriodTime': 17,
#   'reversedPeriodTimeSeconds': 1020,
#   'periodTimeSeconds': 1680,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lamine Yamal',
#    'slug': 'lamine-yamal',
#    'shortName': 'L. Yamal',
#    'position': 'M',
#    'jerseyNumber': '10',
#    'userCount': 1472275,
#    'gender': 'M',
#    'sofascoreId': 'Lamiyamal',
#    'id': 1402912,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'},
#     'shortNameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 17, 'y': 62.4, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 49.9, 'z': 19},
#   'blockCoordinates': {'x': 13.8, 'y': 60.1, 'z': 0},
#   'xg': 0.042449168860912,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266492,
#   'time': 73,
#   'timeSeconds': 4377,
#   'draw': {'start': {'x': 62.4, 'y': 17},
#    'block': {'x': 60.1, 'y': 13.8},
#    'end': {'x': 50.1, 'y': 0},
#    'goal': {'x': 50.1, 'y': 81}},
#   'reversedPeriodTime': 18,
#   'reversedPeriodTimeSeconds': 1023,
#   'periodTimeSeconds': 1677,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Dani Olmo',
#    'slug': 'dani-olmo',
#    'shortName': 'D. Olmo',
#    'position': 'M',
#    'jerseyNumber': '20',
#    'userCount': 194438,
#    'gender': 'M',
#    'sofascoreId': 'DaniOlmo',
#    'id': 789071,
#    'fieldTranslations': {'nameTranslation': {'ar': 'داني أولمو'},
#     'shortNameTranslation': {'ar': 'د. أولمو',
#      'hi': 'डी. ओल्मो',
#      'bn': 'ডি. ওলমো'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'regular',
#   'playerCoordinates': {'x': 11.3, 'y': 55.2, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'close-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 58.3, 'z': 2.8},
#   'xg': 0.14551240205765,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266438,
#   'time': 71,
#   'timeSeconds': 4239,
#   'draw': {'start': {'x': 55.2, 'y': 11.3},
#    'end': {'x': 41.7, 'y': 0},
#    'goal': {'x': 41.7, 'y': 97.2}},
#   'reversedPeriodTime': 20,
#   'reversedPeriodTimeSeconds': 1161,
#   'periodTimeSeconds': 1539,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lamine Yamal',
#    'slug': 'lamine-yamal',
#    'shortName': 'L. Yamal',
#    'position': 'M',
#    'jerseyNumber': '10',
#    'userCount': 1472275,
#    'gender': 'M',
#    'sofascoreId': 'Lamiyamal',
#    'id': 1402912,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'},
#     'shortNameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 22.3, 'y': 80.1, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'left',
#   'goalMouthCoordinates': {'x': 0, 'y': 65.9, 'z': 33.3},
#   'xg': 0.010098215192556,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266473,
#   'time': 69,
#   'timeSeconds': 4139,
#   'draw': {'start': {'x': 80.1, 'y': 22.3},
#    'end': {'x': 34.1, 'y': 0},
#    'goal': {'x': 34.1, 'y': 66.7}},
#   'reversedPeriodTime': 22,
#   'reversedPeriodTimeSeconds': 1261,
#   'periodTimeSeconds': 1439,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lamine Yamal',
#    'slug': 'lamine-yamal',
#    'shortName': 'L. Yamal',
#    'position': 'M',
#    'jerseyNumber': '10',
#    'userCount': 1472275,
#    'gender': 'M',
#    'sofascoreId': 'Lamiyamal',
#    'id': 1402912,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'},
#     'shortNameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 23.5, 'y': 61.5, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'close-high',
#   'goalMouthCoordinates': {'x': 0, 'y': 55, 'z': 51.4},
#   'xg': 0.021369446069002,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266325,
#   'time': 65,
#   'timeSeconds': 3889,
#   'draw': {'start': {'x': 61.5, 'y': 23.5},
#    'end': {'x': 45, 'y': 0},
#    'goal': {'x': 45, 'y': 48.6}},
#   'reversedPeriodTime': 26,
#   'reversedPeriodTimeSeconds': 1511,
#   'periodTimeSeconds': 1189,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Robert Lewandowski',
#    'slug': 'robert-lewandowski',
#    'shortName': 'R. Lewandowski',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 561480,
#    'gender': 'M',
#    'sofascoreId': 'Lewa',
#    'id': 41789,
#    'fieldTranslations': {'nameTranslation': {'ar': 'روبرت ليفاندوفسكي',
#      'hi': 'रॉबर्ट लेवानडॉस्की',
#      'bn': 'রবার্ট লেভান্ডোস্কি'},
#     'shortNameTranslation': {'ar': 'ر. ليفاندوفسكي',
#      'hi': 'आर. लेवानडॉस्की',
#      'bn': 'আর. লেভান্ডোস্কি'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 11.9, 'y': 62.1, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.8, 'z': 18.4},
#   'blockCoordinates': {'x': 1.6, 'y': 52.5, 'z': 0},
#   'xg': 0.0086976829916239,
#   'xgot': 0.049746874719858,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266254,
#   'time': 57,
#   'timeSeconds': 3399,
#   'draw': {'start': {'x': 62.1, 'y': 11.9},
#    'block': {'x': 52.5, 'y': 1.6},
#    'end': {'x': 48.2, 'y': 0},
#    'goal': {'x': 48.2, 'y': 81.6}},
#   'reversedPeriodTime': 34,
#   'reversedPeriodTimeSeconds': 2001,
#   'periodTimeSeconds': 699,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Robert Lewandowski',
#    'slug': 'robert-lewandowski',
#    'shortName': 'R. Lewandowski',
#    'position': 'F',
#    'jerseyNumber': '9',
#    'userCount': 561480,
#    'gender': 'M',
#    'sofascoreId': 'Lewa',
#    'id': 41789,
#    'fieldTranslations': {'nameTranslation': {'ar': 'روبرت ليفاندوفسكي',
#      'hi': 'रॉबर्ट लेवानडॉस्की',
#      'bn': 'রবার্ট লেভান্ডোস্কি'},
#     'shortNameTranslation': {'ar': 'ر. ليفاندوفسكي',
#      'hi': 'आर. लेवानडॉस्की',
#      'bn': 'আর. লেভান্ডোস্কি'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 4, 'y': 54, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 48.7, 'z': 13.3},
#   'blockCoordinates': {'x': 0.90000000000001, 'y': 51.4, 'z': 0},
#   'xg': 0.16607922315598,
#   'xgot': 0.20022957026958,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266209,
#   'time': 57,
#   'timeSeconds': 3387,
#   'draw': {'start': {'x': 54, 'y': 4},
#    'block': {'x': 51.4, 'y': 0.90000000000001},
#    'end': {'x': 51.3, 'y': 0},
#    'goal': {'x': 51.3, 'y': 86.7}},
#   'reversedPeriodTime': 34,
#   'reversedPeriodTimeSeconds': 2013,
#   'periodTimeSeconds': 687,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Raphinha',
#    'slug': 'raphinha',
#    'shortName': 'Raphinha',
#    'position': 'M',
#    'jerseyNumber': '11',
#    'userCount': 747710,
#    'gender': 'M',
#    'sofascoreId': 'Raphinha',
#    'id': 831005,
#    'fieldTranslations': {'nameTranslation': {'ar': 'رافينيا',
#      'hi': 'राफिन्हा',
#      'bn': 'রাফিনহা'},
#     'shortNameTranslation': {'ar': 'رافينيا',
#      'hi': 'राफिन्हा',
#      'bn': 'রাফিনহা'}}},
#   'isHome': True,
#   'shotType': 'save',
#   'situation': 'set-piece',
#   'playerCoordinates': {'x': 25, 'y': 47.5, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 53.2, 'z': 5.1},
#   'blockCoordinates': {'x': 0.90000000000001, 'y': 50.4, 'z': 0},
#   'xg': 0.023051584139466,
#   'xgot': 0.10289180278778,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6266095,
#   'time': 50,
#   'timeSeconds': 2970,
#   'draw': {'start': {'x': 47.5, 'y': 25},
#    'block': {'x': 50.4, 'y': 0.90000000000001},
#    'end': {'x': 46.8, 'y': 0},
#    'goal': {'x': 46.8, 'y': 94.9}},
#   'reversedPeriodTime': 41,
#   'reversedPeriodTimeSeconds': 2430,
#   'periodTimeSeconds': 270,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lucas Boyé',
#    'slug': 'lucas-boye',
#    'shortName': 'L. Boyé',
#    'position': 'F',
#    'jerseyNumber': '15',
#    'userCount': 1118,
#    'gender': 'M',
#    'id': 814385,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لوكاس بويه',
#      'hi': 'लुकास बोये',
#      'bn': 'লুকাস বোয়ে'},
#     'shortNameTranslation': {'ar': 'ل. بويه',
#      'hi': 'एल. बोये',
#      'bn': 'এল. বোয়ে'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 7.5, 'y': 42.1, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'close-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 56.8, 'z': 13.9},
#   'xg': 0.098747037351131,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6265685,
#   'time': 45,
#   'addedTime': 1,
#   'timeSeconds': 2735,
#   'draw': {'start': {'x': 42.1, 'y': 7.5},
#    'end': {'x': 43.2, 'y': 0},
#    'goal': {'x': 43.2, 'y': 86.1}},
#   'reversedPeriodTime': 1,
#   'reversedPeriodTimeSeconds': 2665,
#   'periodTimeSeconds': 35,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lamine Yamal',
#    'slug': 'lamine-yamal',
#    'shortName': 'L. Yamal',
#    'position': 'M',
#    'jerseyNumber': '10',
#    'userCount': 1472275,
#    'gender': 'M',
#    'sofascoreId': 'Lamiyamal',
#    'id': 1402912,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'},
#     'shortNameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'}}},
#   'isHome': True,
#   'shotType': 'post',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 4.2, 'y': 56.6, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 44.5, 'z': 5.7},
#   'xg': 0.20385117828846,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6265673,
#   'time': 44,
#   'timeSeconds': 2622,
#   'draw': {'start': {'x': 56.6, 'y': 4.2},
#    'end': {'x': 55.5, 'y': 0},
#    'goal': {'x': 55.5, 'y': 94.3}},
#   'reversedPeriodTime': 2,
#   'reversedPeriodTimeSeconds': 78,
#   'periodTimeSeconds': 2622,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Pablo Ibáñez',
#    'slug': 'pablo-ibanez-lumbreras',
#    'shortName': 'P. Ibáñez',
#    'position': 'M',
#    'jerseyNumber': '19',
#    'userCount': 312,
#    'gender': 'M',
#    'id': 1084381,
#    'fieldTranslations': {'nameTranslation': {'ar': 'بابلو إيبانيز لومبريراس',
#      'hi': 'पाब्लो इबानेज़ लुम्ब्रेरास',
#      'bn': 'পাবলো ইবনেজ লুম্বেরাস'},
#     'shortNameTranslation': {'ar': 'ب. إ. لومبريراس',
#      'hi': 'पी.आई. लुम्ब्रेरास',
#      'bn': 'পি. আই. লুম্বেরাস'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'set-piece',
#   'playerCoordinates': {'x': 8.1, 'y': 56.5, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'high',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.9, 'z': 70.8},
#   'xg': 0.095218405127525,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6265609,
#   'time': 37,
#   'timeSeconds': 2206,
#   'draw': {'start': {'x': 56.5, 'y': 8.1},
#    'end': {'x': 49.1, 'y': 0},
#    'goal': {'x': 49.1, 'y': 29.2}},
#   'reversedPeriodTime': 9,
#   'reversedPeriodTimeSeconds': 494,
#   'periodTimeSeconds': 2206,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Marc Bernal',
#    'slug': 'marc-bernal',
#    'shortName': 'M. Bernal',
#    'position': 'M',
#    'jerseyNumber': '22',
#    'userCount': 49923,
#    'gender': 'M',
#    'sofascoreId': 'marc_bernal',
#    'id': 1526618,
#    'fieldTranslations': {'nameTranslation': {'ar': 'مارك برنال',
#      'hi': 'मार्क बर्नल',
#      'bn': 'মার্ক বার্নাল'},
#     'shortNameTranslation': {'ar': 'م. برنال',
#      'hi': 'एम. बर्नल',
#      'bn': 'এম. বার্নাল'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 22.8, 'y': 59, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 53.9, 'z': 18.1},
#   'blockCoordinates': {'x': 21.4, 'y': 58.1, 'z': 0},
#   'xg': 0.02102318033576,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6265521,
#   'time': 28,
#   'timeSeconds': 1677,
#   'draw': {'start': {'x': 59, 'y': 22.8},
#    'block': {'x': 58.1, 'y': 21.4},
#    'end': {'x': 46.1, 'y': 0},
#    'goal': {'x': 46.1, 'y': 81.9}},
#   'reversedPeriodTime': 18,
#   'reversedPeriodTimeSeconds': 1023,
#   'periodTimeSeconds': 1677,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Dani Olmo',
#    'slug': 'dani-olmo',
#    'shortName': 'D. Olmo',
#    'position': 'M',
#    'jerseyNumber': '20',
#    'userCount': 194438,
#    'gender': 'M',
#    'sofascoreId': 'DaniOlmo',
#    'id': 789071,
#    'fieldTranslations': {'nameTranslation': {'ar': 'داني أولمو'},
#     'shortNameTranslation': {'ar': 'د. أولمو',
#      'hi': 'डी. ओल्मो',
#      'bn': 'ডি. ওলমো'}}},
#   'isHome': True,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 10.4, 'y': 46.2, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-left',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.9, 'z': 2.5},
#   'xg': 0.35265770554543,
#   'xgot': 0.34220907092094,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6265474,
#   'time': 26,
#   'timeSeconds': 1513,
#   'draw': {'start': {'x': 46.2, 'y': 10.4},
#    'end': {'x': 48.1, 'y': 0},
#    'goal': {'x': 48.1, 'y': 97.5}},
#   'reversedPeriodTime': 20,
#   'reversedPeriodTimeSeconds': 1187,
#   'periodTimeSeconds': 1513,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Abderrahman Rebbach',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'abderrahman-rebbach',
#    'shortName': 'A. Rebbach',
#    'position': 'M',
#    'jerseyNumber': '21',
#    'userCount': 982,
#    'gender': 'M',
#    'id': 1082968,
#    'fieldTranslations': {'nameTranslation': {'ar': 'عبد الرحمان رباش',
#      'hi': 'अब्देर्रहमान रेब्बाक',
#      'bn': 'আবদেররহমান রেবাচ'},
#     'shortNameTranslation': {'ar': 'ع. رباش',
#      'hi': 'ए. रेब्बाक',
#      'bn': 'এ. রেবাখ'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 22.9, 'y': 41.5, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 1.2, 'z': 13.9},
#   'blockCoordinates': {'x': 13.7, 'y': 72.6, 'z': 0},
#   'xg': 0.012899273075163,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6265458,
#   'time': 25,
#   'timeSeconds': 1459,
#   'draw': {'start': {'x': 41.5, 'y': 22.9},
#    'block': {'x': 72.6, 'y': 13.7},
#    'end': {'x': 98.8, 'y': 0},
#    'goal': {'x': 98.8, 'y': 86.1}},
#   'reversedPeriodTime': 21,
#   'reversedPeriodTimeSeconds': 1241,
#   'periodTimeSeconds': 1459,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Jonny Otto',
#    'slug': 'jonny-otto',
#    'shortName': 'J. Otto',
#    'position': 'D',
#    'jerseyNumber': '17',
#    'userCount': 570,
#    'gender': 'M',
#    'id': 235648,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوني أوتو',
#      'hi': 'जॉनी ओट्टो',
#      'bn': 'জনি অটো'},
#     'shortNameTranslation': {'ar': 'ج. أوتو',
#      'hi': 'जे. ओट्टो',
#      'bn': 'জে. ওটো'}}},
#   'isHome': False,
#   'shotType': 'save',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 3.2, 'y': 60.6, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 47.2, 'z': 17.7},
#   'blockCoordinates': {'x': 1, 'y': 53.8, 'z': 0},
#   'xg': 0.20911654829979,
#   'xgot': 0.34610083699226,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6265449,
#   'time': 24,
#   'timeSeconds': 1419,
#   'draw': {'start': {'x': 60.6, 'y': 3.2},
#    'block': {'x': 53.8, 'y': 1},
#    'end': {'x': 52.8, 'y': 0},
#    'goal': {'x': 52.8, 'y': 82.3}},
#   'reversedPeriodTime': 22,
#   'reversedPeriodTimeSeconds': 1281,
#   'periodTimeSeconds': 1419,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Lamine Yamal',
#    'slug': 'lamine-yamal',
#    'shortName': 'L. Yamal',
#    'position': 'M',
#    'jerseyNumber': '10',
#    'userCount': 1472275,
#    'gender': 'M',
#    'sofascoreId': 'Lamiyamal',
#    'id': 1402912,
#    'fieldTranslations': {'nameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'},
#     'shortNameTranslation': {'ar': 'لامين يامال',
#      'hi': 'लामिन यमल',
#      'bn': 'লামিন ইয়ামাল'}}},
#   'isHome': True,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 8.1, 'y': 54.3, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'high-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 51.1, 'z': 28.5},
#   'xg': 0.29564908146858,
#   'xgot': 0.57080179452896,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6265212,
#   'time': 8,
#   'timeSeconds': 475,
#   'draw': {'start': {'x': 54.3, 'y': 8.1},
#    'end': {'x': 48.9, 'y': 0},
#    'goal': {'x': 48.9, 'y': 71.5}},
#   'reversedPeriodTime': 38,
#   'reversedPeriodTimeSeconds': 2225,
#   'periodTimeSeconds': 475,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Eric García',
#    'slug': 'eric-garcia',
#    'shortName': 'E. García',
#    'position': 'D',
#    'jerseyNumber': '24',
#    'userCount': 49945,
#    'gender': 'M',
#    'sofascoreId': 'ericgm3',
#    'id': 876214,
#    'fieldTranslations': {'nameTranslation': {'ar': 'إيريك غارسيا',
#      'hi': 'एरिक गार्सिया',
#      'bn': 'এরিক গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'إ. غارسيا',
#      'hi': 'ई. गार्सिया',
#      'bn': 'ই. গার্সিয়া'}}},
#   'isHome': True,
#   'shotType': 'miss',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 7.5, 'y': 54.5, 'z': 0},
#   'bodyPart': 'head',
#   'goalMouthLocation': 'high',
#   'goalMouthCoordinates': {'x': 0, 'y': 53.4, 'z': 76.4},
#   'xg': 0.15379512310028,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6265184,
#   'time': 7,
#   'timeSeconds': 418,
#   'draw': {'start': {'x': 54.5, 'y': 7.5},
#    'end': {'x': 46.6, 'y': 0},
#    'goal': {'x': 46.6, 'y': 23.6}},
#   'reversedPeriodTime': 39,
#   'reversedPeriodTimeSeconds': 2282,
#   'periodTimeSeconds': 418,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Raphinha',
#    'slug': 'raphinha',
#    'shortName': 'Raphinha',
#    'position': 'M',
#    'jerseyNumber': '11',
#    'userCount': 747710,
#    'gender': 'M',
#    'sofascoreId': 'Raphinha',
#    'id': 831005,
#    'fieldTranslations': {'nameTranslation': {'ar': 'رافينيا',
#      'hi': 'राफिन्हा',
#      'bn': 'রাফিনহা'},
#     'shortNameTranslation': {'ar': 'رافينيا',
#      'hi': 'राफिन्हा',
#      'bn': 'রাফিনহা'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 20.7, 'y': 56.6, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 50.8, 'z': 19},
#   'blockCoordinates': {'x': 10.6, 'y': 52.5, 'z': 0},
#   'xg': 0.029626186937094,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6265191,
#   'time': 7,
#   'timeSeconds': 411,
#   'draw': {'start': {'x': 56.6, 'y': 20.7},
#    'block': {'x': 52.5, 'y': 10.6},
#    'end': {'x': 49.2, 'y': 0},
#    'goal': {'x': 49.2, 'y': 81}},
#   'reversedPeriodTime': 39,
#   'reversedPeriodTimeSeconds': 2289,
#   'periodTimeSeconds': 411,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Raphinha',
#    'slug': 'raphinha',
#    'shortName': 'Raphinha',
#    'position': 'M',
#    'jerseyNumber': '11',
#    'userCount': 747710,
#    'gender': 'M',
#    'sofascoreId': 'Raphinha',
#    'id': 831005,
#    'fieldTranslations': {'nameTranslation': {'ar': 'رافينيا',
#      'hi': 'राफिन्हा',
#      'bn': 'রাফিনহা'},
#     'shortNameTranslation': {'ar': 'رافينيا',
#      'hi': 'राफिन्हा',
#      'bn': 'রাফিনহা'}}},
#   'isHome': True,
#   'shotType': 'block',
#   'situation': 'assisted',
#   'playerCoordinates': {'x': 10.2, 'y': 36.6, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'low-centre',
#   'goalMouthCoordinates': {'x': 0, 'y': 48.6, 'z': 2.8},
#   'blockCoordinates': {'x': 7.5, 'y': 40.2, 'z': 0},
#   'xg': 0.11720819026232,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Antonio Sivera',
#    'slug': 'antonio-sivera',
#    'shortName': 'A. Sivera',
#    'position': 'G',
#    'jerseyNumber': '1',
#    'userCount': 553,
#    'gender': 'M',
#    'id': 369004,
#    'fieldTranslations': {'nameTranslation': {'ar': 'أنطونيو سيفيرا',
#      'hi': 'एंटोनियो सिवेरा',
#      'bn': 'আন্তোনিও সিভেরা'},
#     'shortNameTranslation': {'ar': 'أ. سيفيرا',
#      'hi': 'ए. सिवेरा',
#      'bn': 'এ. সিভেরা'}}},
#   'id': 6265175,
#   'time': 7,
#   'timeSeconds': 383,
#   'draw': {'start': {'x': 36.6, 'y': 10.2},
#    'block': {'x': 40.2, 'y': 7.5},
#    'end': {'x': 51.4, 'y': 0},
#    'goal': {'x': 51.4, 'y': 97.2}},
#   'reversedPeriodTime': 39,
#   'reversedPeriodTimeSeconds': 2317,
#   'periodTimeSeconds': 383,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Abderrahman Rebbach',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'abderrahman-rebbach',
#    'shortName': 'A. Rebbach',
#    'position': 'M',
#    'jerseyNumber': '21',
#    'userCount': 982,
#    'gender': 'M',
#    'id': 1082968,
#    'fieldTranslations': {'nameTranslation': {'ar': 'عبد الرحمان رباش',
#      'hi': 'अब्देर्रहमान रेब्बाक',
#      'bn': 'আবদেররহমান রেবাচ'},
#     'shortNameTranslation': {'ar': 'ع. رباش',
#      'hi': 'ए. रेब्बाक',
#      'bn': 'এ. রেবাখ'}}},
#   'isHome': False,
#   'shotType': 'miss',
#   'situation': 'fast-break',
#   'playerCoordinates': {'x': 6.6, 'y': 30.1, 'z': 0},
#   'bodyPart': 'left-foot',
#   'goalMouthLocation': 'right',
#   'goalMouthCoordinates': {'x': 0, 'y': 33.4, 'z': 2.8},
#   'xg': 0.063774913549423,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6265302,
#   'time': 2,
#   'timeSeconds': 114,
#   'draw': {'start': {'x': 30.1, 'y': 6.6},
#    'end': {'x': 66.6, 'y': 0},
#    'goal': {'x': 66.6, 'y': 97.2}},
#   'reversedPeriodTime': 44,
#   'reversedPeriodTimeSeconds': 2586,
#   'periodTimeSeconds': 114,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Pablo Ibáñez',
#    'slug': 'pablo-ibanez-lumbreras',
#    'shortName': 'P. Ibáñez',
#    'position': 'M',
#    'jerseyNumber': '19',
#    'userCount': 312,
#    'gender': 'M',
#    'id': 1084381,
#    'fieldTranslations': {'nameTranslation': {'ar': 'بابلو إيبانيز لومبريراس',
#      'hi': 'पाब्लो इबानेज़ लुम्ब्रेरास',
#      'bn': 'পাবলো ইবনেজ লুম্বেরাস'},
#     'shortNameTranslation': {'ar': 'ب. إ. لومبريراس',
#      'hi': 'पी.आई. लुम्ब्रेरास',
#      'bn': 'পি. আই. লুম্বেরাস'}}},
#   'isHome': False,
#   'shotType': 'goal',
#   'goalType': 'regular',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 2, 'y': 53.4, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 47.9, 'z': 15.2},
#   'xg': 0.76581919193268,
#   'xgot': 0.83464443683624,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6265098,
#   'time': 1,
#   'timeSeconds': 43,
#   'draw': {'start': {'x': 53.4, 'y': 2},
#    'end': {'x': 52.1, 'y': 0},
#    'goal': {'x': 52.1, 'y': 84.8}},
#   'reversedPeriodTime': 45,
#   'reversedPeriodTimeSeconds': 2657,
#   'periodTimeSeconds': 43,
#   'incidentType': 'shot'},
#  {'player': {'name': 'Victor Parada',
#    'firstName': '',
#    'lastName': '',
#    'slug': 'victor-parada',
#    'shortName': 'V. Parada',
#    'position': 'D',
#    'jerseyNumber': '24',
#    'userCount': 85,
#    'gender': 'M',
#    'id': 985726,
#    'fieldTranslations': {'nameTranslation': {'ar': 'فيكتور بارادا',
#      'hi': 'विक्टर पराडा',
#      'bn': 'ভিক্টর প্যারাডা'},
#     'shortNameTranslation': {'ar': 'ف. بارادا',
#      'hi': 'वी. पराडा',
#      'bn': 'ভি. পারাডা'}}},
#   'isHome': False,
#   'shotType': 'block',
#   'situation': 'corner',
#   'playerCoordinates': {'x': 4, 'y': 48.1, 'z': 0},
#   'bodyPart': 'right-foot',
#   'goalMouthLocation': 'low-right',
#   'goalMouthCoordinates': {'x': 0, 'y': 46.8, 'z': 19},
#   'blockCoordinates': {'x': 1, 'y': 51.6, 'z': 0},
#   'xg': 0.2586270570755,
#   'xgot': 0,
#   'goalkeeper': {'name': 'Joan García',
#    'slug': 'joan-garcia',
#    'shortName': 'J. García',
#    'position': 'G',
#    'jerseyNumber': '13',
#    'userCount': 90542,
#    'gender': 'M',
#    'id': 930267,
#    'fieldTranslations': {'nameTranslation': {'ar': 'جوان جارسيا',
#      'hi': 'जोन गार्सिया',
#      'bn': 'জোয়ান গার্সিয়া'},
#     'shortNameTranslation': {'ar': 'ج. جارسيا',
#      'hi': 'जे. गार्सिया',
#      'bn': 'জে. গার্সিয়া'}}},
#   'id': 6265112,
#   'time': 1,
#   'timeSeconds': 42,
#   'draw': {'start': {'x': 48.1, 'y': 4},
#    'block': {'x': 51.6, 'y': 1},
#    'end': {'x': 53.2, 'y': 0},
#    'goal': {'x': 53.2, 'y': 81}},
#   'reversedPeriodTime': 45,
#   'reversedPeriodTimeSeconds': 2658,
#   'periodTimeSeconds': 42,
#   'incidentType': 'shot'}]

# %%
df = pd.DataFrame(shotmap)

# %%
df.to_csv("sofascore_data.csv")
